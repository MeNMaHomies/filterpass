# %%
import os

from huggingface_hub import login
from dotenv import load_dotenv

load_dotenv()
login(os.getenv("WRITE_API_KEY"))

# %%
from huggingface_hub import upload_file

upload_file(
    path_or_fileobj="checkpoints/best_model_SAP.pt",
    path_in_repo="best_model_SAP.pt",
    repo_id="Menmahomies/SAP_Classifier",
    repo_type="model",
)
# Out:
# Processing Files (1 / 1): 100%|██████████|  379MB /  379MB, 1.19MB/s
# New Data Upload: 100%|██████████|  379MB /  379MB, 1.19MB/s
# CommitInfo(commit_url='https://huggingface.co/Menmahomies/SAP_Classifier/commit/242aed9432dcdc71577f6408e66ed8b7282e2b35', commit_message='Upload best_model_SAP.pt with huggingface_hub', commit_description='', oid='242aed9432dcdc71577f6408e66ed8b7282e2b35', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Menmahomies/SAP_Classifier', endpoint='https://huggingface.co', repo_type='model', repo_id='Menmahomies/SAP_Classifier'), pr_revision=None, pr_num=None)
