# %%
import os

from huggingface_hub import login
from dotenv import load_dotenv

load_dotenv()
login(os.getenv("WRITE_API_KEY"))

# %%
from huggingface_hub import upload_file

upload_file(
    path_or_fileobj="checkpoints/best_model_SAP_v16.pt",
    path_in_repo="best_model_SAP_v14.pt",
    repo_id="Menmahomies/SAP_Model_v14",
    repo_type="model",
)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# CommitInfo(commit_url='https://huggingface.co/Menmahomies/SAP_Model_v14/commit/a1f588c33b1ca2a5b801dd693d250d4d76aeea94', commit_message='Upload best_model_SAP_v14.pt with huggingface_hub', commit_description='', oid='a1f588c33b1ca2a5b801dd693d250d4d76aeea94', pr_url=None, repo_url=RepoUrl('https://huggingface.co/Menmahomies/SAP_Model_v14', endpoint='https://huggingface.co', repo_type='model', repo_id='Menmahomies/SAP_Model_v14'), pr_revision=None, pr_num=None)
